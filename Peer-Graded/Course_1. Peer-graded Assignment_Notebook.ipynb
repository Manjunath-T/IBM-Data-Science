# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Manjunath Talari**
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because i love to work with data and innovative technologies,*
#
# *The Data scientist feild is the perfect place to achieve it and i will definitely work for it and i will achieve it.*

# %% [markdown]
# ### SUM of Two Numbers

# %%
def SumOfNumbers(N1, N2):
    return N1+N2

print(SumOfNumbers(4,4))
# Out:
# 8

# %% [markdown]
# **Horizontal rule**
#
#    ---
#
# **Bulleted list**
#
# - one
# - two
# - three
#
# **Numbered list**
#
# 1. ONE
# 2. TWO
# 3. THREE
#
# **Tables**
#
# | Student_Name | Age | Skill |
# | --- |--- | --- |
# | Mark | 21 | Python |
# | Lisa | 23 | C++ |
#
# **Hyperlinks**
#
# www.google.com
#
# www.facebook.com
#
# www.twitter.com
#
# **Images**
#
# [Git_logo]: https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png "GitLogo"
#
# ![Logo Text Here][Git_logo]
#
#
# **Code/syntax highlighting**
#
# ```python
#
# def SumOfNumbers(N1, N2):
#     return N1+N2
#
# print(SumOfNumbers(4,4))
#
# ```
#
# **Blocked quotes**
#
# > This is the Peer-Graded Assignment
#
# > This Task is for Blocked Quotes
#
# > Yes, It's Working..!
#
#
# **Strikethrough**
#
# ~~This Text is Strike Through.~~
#
# ~~This is Second Strike Through Line.~~
#
# ~~This is Last Strike Through Line.~~
